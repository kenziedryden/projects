# %% [markdown]
# <a href="https://colab.research.google.com/github/kenziedryden/projects/blob/main/data_analysis_(panda%2Btravel_times).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
## I downloaded the csv to my computer and just selected the file
# Out:
#      <input type="file" id="files-28001c58-8e0c-4edb-b23f-3caf4a278eb2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-28001c58-8e0c-4edb-b23f-3caf4a278eb2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded["travel-times.csv"]))
print(df)
## this should import and print the dataset
# Out:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1     1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2     1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3     1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4     1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
# ..         ...       ...        ...     ...       ...       ...       ...
# 200  7/18/2011     08:09     Monday     GSK     54.52     125.6      49.9
# 201  7/14/2011     08:03   Thursday     GSK     50.90     123.7      76.2
# 202  7/13/2011     17:08  Wednesday    Home     51.96     132.6      57.5
# 203  7/12/2011     17:51    Tuesday    Home     53.28     125.8      61.6
# 204  7/11/2011     16:56     Monday    Home     51.73     125.0      62.8
#
#      AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# ...

# %%
df.head()
## shows first five rows of the dataset
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# 0            84.8         NaN       39.3        36.3         No      NaN
# 1            88.9         NaN       37.9        34.9         No      NaN
# 2            85.8         NaN       37.5        35.9         No      NaN
# 3            82.9         NaN       39.8        35.6         No      NaN
# 4            88.1         NaN       36.8        34.8         No      NaN

# %%
df.head(15)
## shows first 15 (or however many you input) rows of dataset
# Out:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1     1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2     1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3     1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4     1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
# 5     1/3/2012     07:57    Tuesday     GSK     51.80     135.8      84.5
# 6     1/2/2012     17:31     Monday    Home     51.37     123.2      82.9
# 7     1/2/2012     07:34     Monday     GSK     49.01     128.3      77.5
# 8   12/23/2011     08:01     Friday     GSK     52.91     130.3      80.9
# 9   12/22/2011     17:19   Thursday    Home     51.17     122.3      70.6
# 10  12/22/2011     08:16   Thursday     GSK     49.15     129.4      74.0
# 11  12/21/2011     07:45  Wednesday     GSK     51.77     124.8      71.7
# ...

# %%
df.shape
## shows number of rows and columns in dataset
# Out:
# (205, 13)

# %%
df.info()
## gives info summary in dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            205 non-null    object
#  1   StartTime       205 non-null    object
#  2   DayOfWeek       205 non-null    object
#  3   GoingTo         205 non-null    object
#  4   Distance        205 non-null    float64
#  5   MaxSpeed        205 non-null    float64
#  6   AvgSpeed        205 non-null    float64
#  7   AvgMovingSpeed  205 non-null    float64
#  8   FuelEconomy     188 non-null    object
#  9   TotalTime       205 non-null    float64
#  10  MovingTime      205 non-null    float64
#  11  Take407All      205 non-null    object
#  12  Comments        24 non-null     object
# dtypes: float64(6), object(7)
# memory usage: 20.9+ KB

# %%
df.drop_duplicates()
## gets rid of any duplicates in dataset, keeps only one (do this just in case)
## this function creates a new dataframe
## (default) drops any duplicates except first one,
## using inplace=True will modify existing dataframe instead of making a new one

df.drop_duplicates(inplace=True)
## you can just assign it like df = df.drop_duplicates() but inplace is better?
# Out:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1     1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2     1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3     1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4     1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
# ..         ...       ...        ...     ...       ...       ...       ...
# 200  7/18/2011     08:09     Monday     GSK     54.52     125.6      49.9
# 201  7/14/2011     08:03   Thursday     GSK     50.90     123.7      76.2
# 202  7/13/2011     17:08  Wednesday    Home     51.96     132.6      57.5
# 203  7/12/2011     17:51    Tuesday    Home     53.28     125.8      61.6
# 204  7/11/2011     16:56     Monday    Home     51.73     125.0      62.8
#
#      AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# ...

# %%
df.columns
## lists all column names
# Out:
# Index(['Date', 'StartTime', 'DayOfWeek', 'GoingTo', 'Distance', 'MaxSpeed',
#        'AvgSpeed', 'AvgMovingSpeed', 'FuelEconomy', 'TotalTime', 'MovingTime',
#        'Take407All', 'Comments'],
#       dtype='object')

# %%
df.rename(columns={
    'DayOfWeek' : 'DayOfTheWeek'
}, inplace=True)

df.columns
## we don't have to use this for this assignment, but this renames any of the column names that you want
# Out:
# Index(['Date', 'StartTime', 'DayOfTheWeek', 'GoingTo', 'Distance', 'MaxSpeed',
#        'AvgSpeed', 'AvgMovingSpeed', 'FuelEconomy', 'TotalTime', 'MovingTime',
#        'Take407All', 'Comments'],
#       dtype='object')

# %%
df.isnull()
## prints entire dataframe but shows value it is null (missing) or not, isn't very helpful (use next func)
# Out:
#       Date  StartTime  DayOfTheWeek  GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0    False      False         False    False     False     False     False
# 1    False      False         False    False     False     False     False
# 2    False      False         False    False     False     False     False
# 3    False      False         False    False     False     False     False
# 4    False      False         False    False     False     False     False
# ..     ...        ...           ...      ...       ...       ...       ...
# 200  False      False         False    False     False     False     False
# 201  False      False         False    False     False     False     False
# 202  False      False         False    False     False     False     False
# 203  False      False         False    False     False     False     False
# 204  False      False         False    False     False     False     False
#
# ...

# %%
df.isnull().sum()
## shows how many null values are in each column, if any
# Out:
# Date                0
# StartTime           0
# DayOfTheWeek        0
# GoingTo             0
# Distance            0
# MaxSpeed            0
# AvgSpeed            0
# AvgMovingSpeed      0
# FuelEconomy        17
# TotalTime           0
# MovingTime          0
# Take407All          0
# Comments          181
# dtype: int64

# %%
df.dropna().shape
## removes the entire row if there is a single null/missing value in the row
## using .shape to show how much data was deleted -originally was (205,13)- this is not a good approach;
## we want to drop columns.
# Out:
# (23, 13)

# %%
df.dropna(axis=1).shape
## axis=1 means columns. this drops columns if there is numll/missing value present
# Out:
# (205, 11)

# %%
df1 = df.copy()
df2 = df.copy()
## makes copies and assigns them

# %%
df2.dropna(axis=1, inplace=True)
df
## removing columns in copy df2
# Out:
#           Date StartTime DayOfTheWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37       Friday    Home     51.29     127.4      78.3
# 1     1/6/2012     08:20       Friday     GSK     51.63     130.3      81.8
# 2     1/4/2012     16:17    Wednesday    Home     51.27     127.4      82.0
# 3     1/4/2012     07:53    Wednesday     GSK     49.17     132.3      74.2
# 4     1/3/2012     18:57      Tuesday    Home     51.15     136.2      83.4
# ..         ...       ...          ...     ...       ...       ...       ...
# 200  7/18/2011     08:09       Monday     GSK     54.52     125.6      49.9
# 201  7/14/2011     08:03     Thursday     GSK     50.90     123.7      76.2
# 202  7/13/2011     17:08    Wednesday    Home     51.96     132.6      57.5
# 203  7/12/2011     17:51      Tuesday    Home     53.28     125.8      61.6
# 204  7/11/2011     16:56       Monday    Home     51.73     125.0      62.8
#
# ...

# %%
df.describe()
## gives summary descriptions
# Out:
#          Distance    MaxSpeed    AvgSpeed  AvgMovingSpeed   TotalTime  \
# count  205.000000  205.000000  205.000000      205.000000  205.000000
# mean    50.981512  127.591707   74.477561       81.975610   41.904390
# std      1.321205    4.128450   11.409816       10.111544    6.849476
# min     48.320000  112.200000   38.100000       50.300000   28.200000
# 25%     50.650000  124.900000   68.900000       76.600000   38.400000
# 50%     51.140000  127.400000   73.600000       81.400000   41.300000
# 75%     51.630000  129.800000   79.900000       86.000000   44.400000
# max     60.320000  140.900000  107.700000      112.100000   82.300000
#
#        MovingTime
# count  205.000000
# mean    37.871707
# std      4.835072
# min     27.100000
# 25%     35.700000
# 50%     37.600000
# 75%     39.900000
# max     62.400000

# %%
df.select_dtypes(exclude='object').corr()
## makes correlations in dataset. need to incluse the exclusion to get rid of nonnumerical values
## closer to -1, strong (-) correlation; closer to 1, strong (+) correlation
# Out:
#                 Distance  MaxSpeed  AvgSpeed  AvgMovingSpeed  TotalTime  \
# Distance        1.000000  0.145091 -0.006445        0.011874   0.197207
# MaxSpeed        0.145091  1.000000  0.253869        0.257823  -0.198775
# AvgSpeed       -0.006445  0.253869  1.000000        0.872143  -0.877806
# AvgMovingSpeed  0.011874  0.257823  0.872143        1.000000  -0.856986
# TotalTime       0.197207 -0.198775 -0.877806       -0.856986   1.000000
# MovingTime      0.197044 -0.222574 -0.835814       -0.944433   0.920935
#
#                 MovingTime
# Distance          0.197044
# MaxSpeed         -0.222574
# AvgSpeed         -0.835814
# AvgMovingSpeed   -0.944433
# TotalTime         0.920935
# MovingTime        1.000000

# %%
df.iloc[10:14]
## getting rows 11-14
# Out:
#           Date StartTime DayOfTheWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 10  12/22/2011     08:16     Thursday     GSK     49.15     129.4      74.0
# 11  12/21/2011     07:45    Wednesday     GSK     51.77     124.8      71.7
# 12  12/20/2011     16:05      Tuesday    Home     51.45     130.1      75.2
# 13  12/20/2011     06:04      Tuesday     GSK     49.01     119.0      77.4
#
#     AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# 10            81.4        8.89       39.8        36.2         No      NaN
# 11            78.9        8.89       43.3        39.4         No      NaN
# 12            82.7        8.89       41.1        37.3         No      NaN
# 13            82.0        8.89       38.0        35.9         No      NaN

# %%
df[(df['Date'] >= "11/13/2011") & (df['Date'] <= "01/06/2012")]
## getting range 11/3/2011 to 01/06/2012, ran out of time in class
# Out:
# Empty DataFrame
# Columns: [Date, StartTime, DayOfTheWeek, GoingTo, Distance, MaxSpeed, AvgSpeed, AvgMovingSpeed, FuelEconomy, TotalTime, MovingTime, Take407All, Comments]
# Index: []

# %%
## Do plotting for homework
df.plot(kind='scatter', x="AvgSpeed", y="MaxSpeed", title="Average Speed vs Max Speed")
# Out:
# <Axes: title={'center': 'Average Speed vs Max Speed'}, xlabel='AvgSpeed', ylabel='MaxSpeed'>

# %%
df.plot(kind='hist', x= "TotalTime", y= "MovingTime", title= "Total Time vs. Moving Time")
# Out:
# <Axes: title={'center': 'Total Time vs. Moving Time'}, ylabel='Frequency'>

# %%
df['Distance'].plot(kind="box")
df['Distance'].describe()
# Out:
# count    205.000000
# mean      50.981512
# std        1.321205
# min       48.320000
# 25%       50.650000
# 50%       51.140000
# 75%       51.630000
# max       60.320000
# Name: Distance, dtype: float64
